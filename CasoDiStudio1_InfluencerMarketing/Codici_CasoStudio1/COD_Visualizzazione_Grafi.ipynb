# %% [markdown]
# Script phython per generare i grafi dei dataset 100x100 dei 3 scenari
# OSS: nno è possibile generare i grafi del dataset 1.000.000 x 1.000.000

# %%
# !pip install networkx

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

#codice che genera grafo ottimizzato per proiettore (colori più scuri, legende più grandi, ecc.)

def genera_grafo_scenario1(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 1 (Influencer Marketing)")
    inizio = time.time()
    
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())
    G.remove_edges_from(list(nx.selfloop_edges(G)))

    print("🧠 Classificazione dei nodi...")
    influencers = [0, 1, 2]
    nodi_speciali = influencers
    nodi_normali = [n for n in G.nodes() if n not in nodi_speciali]

    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    # MODIFICA: Tela più grande
    plt.figure(figsize=(20, 15)) 
    pos = nx.spring_layout(G, k=0.9, iterations=100, seed=42) 

    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    # MODIFICA: Nodi raddoppiati per riempire la scena
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='#CC0000', node_size=1800, label='Influencer (0, 1, 2)')
    nx.draw_networkx_nodes(G, pos, nodelist=nodi_normali, node_color='#003366', node_size=150, alpha=0.85, label='Bot / Follower Inattivi')

    # MODIFICA: Archi più spessi (width=1.5) e frecce più grandi (arrowsize=20)
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='#666666', width=1.5, arrows=True, arrowsize=20)

    # MODIFICA: Font dei numeri più grande
    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=16, font_weight='bold', font_color='white')

    # MODIFICA: Titolo leggermente più grande
    plt.title("Caso di Studio 1: Influencer Marketing (Scenario 1)", fontsize=22, fontweight='bold', pad=20)
    
    # MODIFICA: Legenda spinta dentro l'area vuota a destra (0.75)
    plt.legend(
        scatterpoints=1, 
        bbox_to_anchor=(0.75, 0.05), # <-- Valore X abbassato per spostarla a sinistra
        loc='lower left', 
        fontsize=20, 
        markerscale=0.9, 
        framealpha=1,
        borderpad=1.0,       
        labelspacing=1.0,    
        handletextpad=1.0    
    )
    
    plt.margins(0)
    plt.axis('off')

    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")


FILE_INPUT = '../DataSet_CasoStudio1/Rete_100/dataset_scenario1.csv'
FILE_OUTPUT = '../Grafi_CasoStudio1/Grafo_Scenario1_Proiettore.png'

genera_grafo_scenario1(FILE_INPUT, FILE_OUTPUT)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 1 (Influencer Marketing)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario1.csv...
# 🧠 Classificazione dei nodi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario1_Proiettore.png
# ⏱️ Tempo impiegato: 0.84 secondi!

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt


def genera_grafo_scenario1(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 1 (Influencer Marketing)")
    inizio = time.time()
    
    # ===============================================
    # PASSO 1: CARICAMENTO DATASET E CREAZIONE GRAFO
    # ===============================================
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    # Crea il grafo orientato e rimuove eventuali auto-loop
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())
    G.remove_edges_from(list(nx.selfloop_edges(G)))

    # ===============================================
    # PASSO 2: DEFINIZIONE DEI GRUPPI STRATEGICI
    # ===============================================
    print("🧠 Classificazione dei nodi...")
    influencers = [0, 1, 2]
    
    # Nodi speciali (quelli che avranno i numeri stampati)
    nodi_speciali = influencers
    
    # Tutti gli altri nodi (Bot inattivi)
    nodi_normali = [n for n in G.nodes() if n not in nodi_speciali]

    # ===============================================
    # PASSO 3: CALCOLO DEL LAYOUT SPAZIALE
    # ===============================================
    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    plt.figure(figsize=(16, 12)) 
    
    # Stesso K, iterazioni e seed per massima coerenza visiva con gli altri scenari
    pos = nx.spring_layout(G, k=0.9, iterations=100, seed=42) 

    # ===============================================
    # PASSO 4: DISEGNO DEI NODI E DEGLI ARCHI
    # ===============================================
    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    
    # Disegno le categorie con colori e dimensioni allineati al resto della tesi
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='red', node_size=900, label='Influencer (0, 1, 2)')
    nx.draw_networkx_nodes(G, pos, nodelist=nodi_normali, node_color='skyblue', node_size=60, alpha=0.5, label='Bot / Follower Inattivi')

    # Archi leggeri identici agli altri scenari
    nx.draw_networkx_edges(G, pos, alpha=0.15, edge_color='gray', arrows=True, arrowsize=12)

    # ===============================================
    # PASSO 5: ETICHETTE E DETTAGLI ESTETICI
    # ===============================================
    # Inserimento dei numeri SOLO per i nodi speciali (Influencer)
    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=12, font_weight='bold', font_color='black')

    plt.title("Caso di Studio 1: Influencer Marketing (Scenario 1)", fontsize=18, fontweight='bold', pad=20)
    
    # Legenda esterna rimpicciolita (uguale agli altri Scenari)
    plt.legend(scatterpoints=1, bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=12, markerscale=0.3)
    
    plt.margins(0)
    plt.axis('off')

    # ===============================================
    # PASSO 6: SALVATAGGIO AUTOMATICO
    # ===============================================
    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)
        print(f"📁 Creata cartella: {cartella_destinazione}")

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")


# ==========================================
# ESECUZIONE PER LO SCENARIO 1
# ==========================================

# Assicurati che i percorsi siano corretti per la tua struttura di cartelle
FILE_INPUT = '../DataSet_CasoStudio1/Rete_100/dataset_scenario1.csv'
FILE_OUTPUT = '../Grafi_CasoStudio1/Grafo_Scenario1.png'

genera_grafo_scenario1(FILE_INPUT, FILE_OUTPUT)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 1 (Influencer Marketing)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario1.csv...
# 🧠 Classificazione dei nodi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario1.png
# ⏱️ Tempo impiegato: 0.73 secondi!

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

#codice che genera grafo ottimizzato per proiettore (colori più scuri, legende più grandi, ecc.)

def genera_grafo_scenario2(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 2 (Rete Mista e Hub)")
    inizio = time.time()
    
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())
    G.remove_edges_from(list(nx.selfloop_edges(G)))

    print("🧠 Classificazione dei nodi...")
    influencers = [0, 1, 2]
    hubs = [60, 70, 80, 90]
    bots = [n for n in G.nodes() if 3 <= n <= 50]
    utenti_attivi = [n for n in G.nodes() if n >= 51 and n not in hubs]
    nodi_speciali = influencers + hubs

    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    plt.figure(figsize=(20, 15)) 
    pos = nx.spring_layout(G, k=0.6, iterations=100, seed=42) 

    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='#CC0000', node_size=1800, label='Influencer (0, 1, 2)')
    nx.draw_networkx_nodes(G, pos, nodelist=hubs, node_color='#CC7000', node_size=1400, label='Hub Strategici (60, 70, 80, 90)')
    nx.draw_networkx_nodes(G, pos, nodelist=utenti_attivi, node_color='#006600', node_size=150, alpha=0.85, label='Utenti Attivi (51-99)')
    nx.draw_networkx_nodes(G, pos, nodelist=bots, node_color='#003366', node_size=150, alpha=0.85, label='Bot Inattivi (3-50)')

    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='#666666', width=1.5, arrows=True, arrowsize=20)

    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=16, font_weight='bold', font_color='white')

    plt.title("Caso di Studio 1: Rete Mista e Hub Strategici (Scenario 2)", fontsize=22, fontweight='bold', pad=20)
    
    # MODIFICA: Legenda rimessa fuori dal grafo, leggermente rimpicciolita
    plt.legend(
        scatterpoints=1, 
        bbox_to_anchor=(1.02, 0.0),  # La sposta totalmente fuori dal grafico a destra
        loc='lower left',            # L'angolo in basso a sinistra della legenda tocca l'ancora
        fontsize=18,                 # Font ridotto da 20 a 18
        markerscale=0.8,             # Pallini ridotti di un soffio
        framealpha=1,
        borderpad=1.0,
        labelspacing=1.0,
        handletextpad=1.0
    )
    
    plt.margins(0)
    plt.axis('off')

    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")


FILE_INPUT = '../DataSet_CasoStudio1/Rete_100/dataset_scenario2.csv'
FILE_OUTPUT = '../Grafi_CasoStudio1/Grafo_Scenario2_Proiettore.png'

genera_grafo_scenario2(FILE_INPUT, FILE_OUTPUT)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 2 (Rete Mista e Hub)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario2.csv...
# 🧠 Classificazione dei nodi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario2_Proiettore.png
# ⏱️ Tempo impiegato: 0.82 secondi!

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

def genera_grafo_scenario2(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 2 (Rete Mista e Hub)")
    inizio = time.time()
    
    # ===============================================
    # PASSO 1: CARICAMENTO DATASET E CREAZIONE GRAFO
    # ===============================================
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    # Crea il grafo orientato (e rimuove eventuali self-loops come nel tuo codice originale)
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())
    G.remove_edges_from(list(nx.selfloop_edges(G)))

    # ===============================================
    # PASSO 2: DEFINIZIONE DEI GRUPPI STRATEGICI
    # ===============================================
    print("🧠 Classificazione dei nodi...")
    influencers = [0, 1, 2]
    hubs = [60, 70, 80, 90]
    
    # I bot erano stati generati dal nodo 3 al nodo 50
    bots = [n for n in G.nodes() if 3 <= n <= 50]
    
    # Gli utenti attivi organici vanno dal 51 in poi (escludendo gli Hub)
    utenti_attivi = [n for n in G.nodes() if n >= 51 and n not in hubs]
    
    # Nodi speciali (quelli che avranno i numeri stampati)
    nodi_speciali = influencers + hubs

    # ===============================================
    # PASSO 3: CALCOLO DEL LAYOUT SPAZIALE
    # ===============================================
    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    plt.figure(figsize=(16, 12)) 
    
    # Stesso K, iterazioni e seed dello Scenario 3 per massima coerenza visiva
    pos = nx.spring_layout(G, k=0.6, iterations=100, seed=42) 

    # ===============================================
    # PASSO 4: DISEGNO DEI NODI E DEGLI ARCHI
    # ===============================================
    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    
    # Disegno le categorie assegnando verde agli utenti attivi e azzurro ai bot
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='red', node_size=900, label='Influencer (0, 1, 2)')
    nx.draw_networkx_nodes(G, pos, nodelist=hubs, node_color='orange', node_size=700, label='Hub Strategici (60, 70, 80, 90)')
    nx.draw_networkx_nodes(G, pos, nodelist=utenti_attivi, node_color='lightgreen', node_size=60, alpha=0.6, label='Utenti Attivi (51-99)')
    nx.draw_networkx_nodes(G, pos, nodelist=bots, node_color='skyblue', node_size=60, alpha=0.6, label='Bot Inattivi (3-50)')

    # Archi leggeri identici allo Scenario 3
    nx.draw_networkx_edges(G, pos, alpha=0.15, edge_color='gray', arrows=True, arrowsize=12)

    # ===============================================
    # PASSO 5: ETICHETTE E DETTAGLI ESTETICI
    # ===============================================
    # Inserimento dei numeri SOLO per i nodi speciali (Influencer e Hub)
    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=12, font_weight='bold', font_color='black')

    plt.title("Caso di Studio 1: Rete Mista e Hub Strategici (Scenario 2)", fontsize=18, fontweight='bold', pad=20)
    
    # Legenda esterna rimpicciolita (uguale allo Scenario 3)
    plt.legend(scatterpoints=1, bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=12, markerscale=0.3)
    
    plt.margins(0)
    plt.axis('off')

    # ===============================================
    # PASSO 6: SALVATAGGIO AUTOMATICO
    # ===============================================
    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)
        print(f"📁 Creata cartella: {cartella_destinazione}")

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")


# ==========================================
# ESECUZIONE PER LO SCENARIO 2
# ==========================================

# Assicurati che il percorso del CSV di input sia corretto per la tua cartella
FILE_INPUT = '../DataSet_CasoStudio1/Rete_100/dataset_scenario2.csv'
FILE_OUTPUT = '../Grafi_CasoStudio1/Grafo_Scenario2.png'

genera_grafo_scenario2(FILE_INPUT, FILE_OUTPUT)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 2 (Rete Mista e Hub)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario2.csv...
# 🧠 Classificazione dei nodi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario2.png
# ⏱️ Tempo impiegato: 0.65 secondi!

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

#codice che genera grafo ottimizzato per proiettore (colori più scuri, legende più grandi, ecc.)

def genera_grafo_scenario_3(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 3 (Topologia Small-World)")
    inizio = time.time()
    
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())

    print("🧠 Classificazione dei nodi secondo le logiche di tesi...")
    influencers = [0, 1, 2]
    micro_hubs = [10, 15, 25, 45, 55, 80]
    nodi_speciali = influencers + micro_hubs
    follower_organici = [n for n in G.nodes() if n not in nodi_speciali]

    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    # MODIFICA: Tela più grande
    plt.figure(figsize=(20, 15)) 
    pos = nx.spring_layout(G, k=0.6, iterations=100, seed=42) 

    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    # MODIFICA: Nodi raddoppiati per riempire la scena
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='#CC0000', node_size=1800, label='Influencer (0, 1, 2)')
    nx.draw_networkx_nodes(G, pos, nodelist=micro_hubs, node_color='#B8860B', node_size=1200, label='Micro-Hub (10, 15, 25, 45, 55, 80)')
    nx.draw_networkx_nodes(G, pos, nodelist=follower_organici, node_color='#005580', node_size=150, alpha=0.85, label='Follower Organici (Cluster)')

    # MODIFICA: Archi più spessi e frecce più grandi
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='#666666', width=1.5, arrows=True, arrowsize=20)

    # MODIFICA: Font dei numeri più grande
    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=16, font_weight='bold', font_color='white')

    # MODIFICA: Titolo più grande
    plt.title("Caso di Studio 1: Community Organica 100% Attiva (Scenario 3)", fontsize=22, fontweight='bold', pad=20)
    
    # MODIFICA: Legenda spinta dentro l'area vuota
    plt.legend(
        scatterpoints=1, 
        bbox_to_anchor=(0.75, 0.05), # Posizione che fa rientrare la legenda nel grafo
        loc='lower left', 
        fontsize=20, 
        markerscale=0.9, 
        framealpha=1,
        borderpad=1.0,
        labelspacing=1.0,
        handletextpad=1.0
    )
    
    plt.margins(0)
    plt.axis('off')

    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")

INPUT_CSV = '../DataSet_CasoStudio1/Rete_100/dataset_scenario3.csv'
OUTPUT_PNG = '../Grafi_CasoStudio1/Grafo_Scenario3_Proiettore.png'

genera_grafo_scenario_3(INPUT_CSV, OUTPUT_PNG)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 3 (Topologia Small-World)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario3.csv...
# 🧠 Classificazione dei nodi secondo le logiche di tesi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario3_Proiettore.png
# ⏱️ Tempo impiegato: 0.70 secondi!

# %%
import os
import time
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

def genera_grafo_scenario_3(percorso_input, percorso_output):
    print(f"⚙️ Inizio generazione grafo: Scenario 3 (Topologia Small-World)")
    inizio = time.time()
    
    # ===============================================
    # PASSO 1: CARICAMENTO DATASET E CREAZIONE GRAFO
    # ===============================================
    print(f"📥 Caricamento del dataset da: {percorso_input}...")
    df = pd.read_csv(percorso_input)
    
    # Crea il grafo orientato
    G = nx.from_pandas_edgelist(df, 'Source', 'Target', create_using=nx.DiGraph())

    # ===============================================
    # PASSO 2: DEFINIZIONE DEI GRUPPI STRATEGICI (AGGIORNATO)
    # ===============================================
    print("🧠 Classificazione dei nodi secondo le logiche di tesi...")
    influencers = [0, 1, 2]
    
    # Uniamo tutti i nodi strategici nella lista dei micro-hub come confermato dalle analisi
    micro_hubs = [10, 15, 25, 45, 55, 80]
    
    nodi_speciali = influencers + micro_hubs
    
    # Tutti gli altri nodi (incluso il 95) diventano normali follower organici
    follower_organici = [n for n in G.nodes() if n not in nodi_speciali]

    # ===============================================
    # PASSO 3: CALCOLO DEL LAYOUT SPAZIALE
    # ===============================================
    print("🌐 Calcolo della disposizione spaziale (Layout espanso)...")
    plt.figure(figsize=(16, 12)) 
    
    pos = nx.spring_layout(G, k=0.6, iterations=100, seed=42) 

    # ===============================================
    # PASSO 4: DISEGNO DEI NODI E DEGLI ARCHI (RIDOTTO A 3 CATEGORIE)
    # ===============================================
    print("🎨 Disegno della rete (Colori e Dimensioni)...")
    
    # 1. Influencer
    nx.draw_networkx_nodes(G, pos, nodelist=influencers, node_color='red', node_size=900, label='Influencer (0, 1, 2)')
    
    # 2. Tutti i Micro-Hub
    nx.draw_networkx_nodes(G, pos, nodelist=micro_hubs, node_color='gold', node_size=600, label='Micro-Hub (10, 15, 25, 45, 55, 80)')
    
    # 3. Follower Organici
    nx.draw_networkx_nodes(G, pos, nodelist=follower_organici, node_color='lightblue', node_size=60, alpha=0.5, label='Follower Organici (Cluster)')

    # Archi
    nx.draw_networkx_edges(G, pos, alpha=0.15, edge_color='gray', arrows=True, arrowsize=12)

    # ===============================================
    # PASSO 5: ETICHETTE E DETTAGLI ESTETICI
    # ===============================================
    # Le etichette numeriche appariranno SOLO per Influencer e Micro-Hub
    labels = {n: str(n) for n in nodi_speciali}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=12, font_weight='bold', font_color='black')

    plt.title("Caso di Studio 1: Community Organica 100% Attiva (Scenario 3)", fontsize=18, fontweight='bold', pad=20)
    
    plt.legend(scatterpoints=1, bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=12, markerscale=0.3)
    
    plt.margins(0)
    plt.axis('off')

    # ===============================================
    # PASSO 6: SALVATAGGIO AUTOMATICO
    # ===============================================
    cartella_destinazione = os.path.dirname(percorso_output)
    if not os.path.exists(cartella_destinazione):
        os.makedirs(cartella_destinazione)
        print(f"📁 Creata cartella: {cartella_destinazione}")

    print(f"💾 Salvataggio in corso...")
    plt.savefig(percorso_output, dpi=300, bbox_inches='tight')
    
    plt.close() 

    fine = time.time()
    print(f"✅ Grafo salvato con successo in: {percorso_output}")
    print(f"⏱️ Tempo impiegato: {fine - inizio:.2f} secondi!\n")

# =====================================================================
# ESECUZIONE
# =====================================================================
INPUT_CSV = '../DataSet_CasoStudio1/Rete_100/dataset_scenario3.csv'
OUTPUT_PNG = '../Grafi_CasoStudio1/Grafo_Scenario3.png'

genera_grafo_scenario_3(INPUT_CSV, OUTPUT_PNG)
# Out:
# ⚙️ Inizio generazione grafo: Scenario 3 (Topologia Small-World)
# 📥 Caricamento del dataset da: ../DataSet_CasoStudio1/Rete_100/dataset_scenario3.csv...
# 🧠 Classificazione dei nodi secondo le logiche di tesi...
# 🌐 Calcolo della disposizione spaziale (Layout espanso)...
# 🎨 Disegno della rete (Colori e Dimensioni)...
# 💾 Salvataggio in corso...
# ✅ Grafo salvato con successo in: ../Grafi_CasoStudio1/Grafo_Scenario3.png
# ⏱️ Tempo impiegato: 0.61 secondi!
